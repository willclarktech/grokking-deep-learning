# %%
# Overfitting MNIST

# %%
import numpy as np
from keras.datasets import mnist
np.random.seed(1)
# Out:
# Using TensorFlow backend.

# %%
relu = lambda x: (x > 0) * x
relu2deriv = lambda x: x > 0

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000])

# %%
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

# %%
test_images = x_test.reshape(len(x_test), 28*28) / 255

# %%
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
alpha = 0.005
iterations = 300
hidden_size = 100
pixels_per_image = 784
num_labels = 10

# %%
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error = 0.0
    correct_count = 0
    
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((layer_2 - labels[i:i+1]) **2)
        correct_count += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        
        layer_2_delta = layer_2 - labels[i:i+1]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)
    
    if not j % 10 or j == iterations - 1:
        test_error = 0.0
        test_correct_count = 0
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            
            test_error += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
            test_correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        

        print("\nI:" + str(j) + " Train error:" + str(error/float(len(images)))[0:5] + " Train accuracy:" + str(correct_count/float(len(images))))
        print("Test error:" + str(test_error/float(len(test_images)))[0:5] + " Test accuracy:" + str(test_correct_count/float(len(test_images))))
# Out:
# I:0 Train error:0.664 Train accuracy:0.634
# Test error:0.569 Test accuracy:0.6984
#
# I:10 Train error:0.161 Train accuracy:0.971
# Test error:0.319 Test accuracy:0.8765
#
# I:20 Train error:0.096 Train accuracy:0.997
# Test error:0.297 Test accuracy:0.8858
#
# I:30 Train error:0.065 Train accuracy:1.0
# Test error:0.293 Test accuracy:0.8876
#
# I:40 Train error:0.047 Train accuracy:1.0
# Test error:0.294 Test accuracy:0.8888
#
# I:50 Train error:0.036 Train accuracy:1.0
# Test error:0.296 Test accuracy:0.8877
#
# I:60 Train error:0.028 Train accuracy:1.0
# Test error:0.297 Test accuracy:0.8868
#
# I:70 Train error:0.023 Train accuracy:1.0
# Test error:0.299 Test accuracy:0.8869
#
# I:80 Train error:0.019 Train accuracy:1.0
# Test error:0.300 Test accuracy:0.8863
#
# I:90 Train error:0.016 Train accuracy:1.0
# Test error:0.302 Test accuracy:0.8847
#
# I:100 Train error:0.013 Train accuracy:1.0
# Test error:0.303 Test accuracy:0.8846
#
# I:110 Train error:0.011 Train accuracy:1.0
# Test error:0.305 Test accuracy:0.8838
#
# I:120 Train error:0.010 Train accuracy:1.0
# Test error:0.306 Test accuracy:0.883
#
# I:130 Train error:0.009 Train accuracy:1.0
# Test error:0.307 Test accuracy:0.8826
#
# I:140 Train error:0.008 Train accuracy:1.0
# Test error:0.308 Test accuracy:0.8822
#
# I:150 Train error:0.007 Train accuracy:1.0
# Test error:0.309 Test accuracy:0.8813
#
# I:160 Train error:0.006 Train accuracy:1.0
# Test error:0.310 Test accuracy:0.8803
#
# I:170 Train error:0.006 Train accuracy:1.0
# Test error:0.311 Test accuracy:0.88
#
# I:180 Train error:0.005 Train accuracy:1.0
# Test error:0.311 Test accuracy:0.8798
#
# I:190 Train error:0.005 Train accuracy:1.0
# Test error:0.312 Test accuracy:0.8797
#
# I:200 Train error:0.004 Train accuracy:1.0
# Test error:0.313 Test accuracy:0.88
#
# I:210 Train error:0.004 Train accuracy:1.0
# Test error:0.313 Test accuracy:0.8795
#
# I:220 Train error:0.003 Train accuracy:1.0
# Test error:0.314 Test accuracy:0.8786
#
# I:230 Train error:0.003 Train accuracy:1.0
# Test error:0.315 Test accuracy:0.8779
#
# I:240 Train error:0.003 Train accuracy:1.0
# Test error:0.315 Test accuracy:0.8777
#
# I:250 Train error:0.003 Train accuracy:1.0
# Test error:0.316 Test accuracy:0.8775
#
# I:260 Train error:0.003 Train accuracy:1.0
# Test error:0.316 Test accuracy:0.8779
#
# I:270 Train error:0.002 Train accuracy:1.0
# Test error:0.317 Test accuracy:0.8775
#
# I:280 Train error:0.002 Train accuracy:1.0
# Test error:0.317 Test accuracy:0.8765
#
# I:290 Train error:0.002 Train accuracy:1.0
# Test error:0.317 Test accuracy:0.876
#
# I:299 Train error:0.002 Train accuracy:1.0
# Test error:0.318 Test accuracy:0.876

# %%
# Dropout

# %%
alpha = 0.005
iterations = 300
hidden_size = 100
pixels_per_image = 784
num_labels = 10

# %%
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error = 0.0
    correct_count = 0
    
    for i in range(len(images)):
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_1 *= dropout_mask * 2
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((layer_2 - labels[i:i+1]) ** 2)
        correct_count += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        
        layer_2_delta = layer_2 - labels[i:i+1]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        layer_1_delta *= dropout_mask
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)
    
    if not j % 10 or j == iterations - 1:
        test_error = 0.0
        test_correct_count = 0
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            
            test_error += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
            test_correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
        print("\nI:" + str(j) + " Train error:" + str(error/float(len(images)))[0:5] + " Train accuracy:" + str(correct_count/float(len(images))))
        print("Test error:" + str(test_error/float(len(test_images)))[0:5] + " Test accuracy:" + str(test_correct_count/float(len(test_images))))
i = 0
layer_0 = images[i:i+1]
# Out:
# I:0 Train error:0.899 Train accuracy:0.381
# Test error:0.634 Test accuracy:0.6519
#
# I:10 Train error:0.396 Train accuracy:0.822
# Test error:0.360 Test accuracy:0.8334
#
# I:20 Train error:0.319 Train accuracy:0.881
# Test error:0.318 Test accuracy:0.8515
#
# I:30 Train error:0.278 Train accuracy:0.909
# Test error:0.302 Test accuracy:0.8649
#
# I:40 Train error:0.257 Train accuracy:0.914
# Test error:0.291 Test accuracy:0.8702
#
# I:50 Train error:0.246 Train accuracy:0.945
# Test error:0.284 Test accuracy:0.871
#
# I:60 Train error:0.231 Train accuracy:0.953
# Test error:0.289 Test accuracy:0.8736
#
# I:70 Train error:0.222 Train accuracy:0.962
# Test error:0.281 Test accuracy:0.8762
#
# I:80 Train error:0.203 Train accuracy:0.967
# Test error:0.277 Test accuracy:0.8791
#
# I:90 Train error:0.201 Train accuracy:0.961
# Test error:0.284 Test accuracy:0.8737
#
# I:100 Train error:0.204 Train accuracy:0.969
# Test error:0.281 Test accuracy:0.8771
#
# I:110 Train error:0.186 Train accuracy:0.964
# Test error:0.283 Test accuracy:0.8706
#
# I:120 Train error:0.187 Train accuracy:0.97
# Test error:0.282 Test accuracy:0.8709
#
# I:130 Train error:0.182 Train accuracy:0.972
# Test error:0.285 Test accuracy:0.8734
#
# I:140 Train error:0.183 Train accuracy:0.968
# Test error:0.286 Test accuracy:0.8732
#
# I:150 Train error:0.190 Train accuracy:0.969
# Test error:0.288 Test accuracy:0.8719
#
# I:160 Train error:0.190 Train accuracy:0.975
# Test error:0.276 Test accuracy:0.8762
#
# I:170 Train error:0.170 Train accuracy:0.977
# Test error:0.289 Test accuracy:0.8694
#
# I:180 Train error:0.183 Train accuracy:0.977
# Test error:0.273 Test accuracy:0.8792
#
# I:190 Train error:0.166 Train accuracy:0.976
# Test error:0.282 Test accuracy:0.872
#
# I:200 Train error:0.170 Train accuracy:0.969
# Test error:0.279 Test accuracy:0.8722
#
# I:210 Train error:0.166 Train accuracy:0.975
# Test error:0.285 Test accuracy:0.8724
#
# I:220 Train error:0.174 Train accuracy:0.967
# Test error:0.285 Test accuracy:0.8707
#
# I:230 Train error:0.155 Train accuracy:0.98
# Test error:0.283 Test accuracy:0.8687
#
# I:240 Train error:0.157 Train accuracy:0.977
# Test error:0.290 Test accuracy:0.8678
#
# I:250 Train error:0.155 Train accuracy:0.982
# Test error:0.286 Test accuracy:0.8671
#
# I:260 Train error:0.150 Train accuracy:0.986
# Test error:0.293 Test accuracy:0.8684
#
# I:270 Train error:0.158 Train accuracy:0.982
# Test error:0.287 Test accuracy:0.8705
#
# I:280 Train error:0.156 Train accuracy:0.979
# Test error:0.284 Test accuracy:0.8673
#
# I:290 Train error:0.152 Train accuracy:0.986
# Test error:0.284 Test accuracy:0.8716
#
# I:299 Train error:0.156 Train accuracy:0.984
# Test error:0.293 Test accuracy:0.8682

# %%
# Mini-batched gradient descent

# %%
alpha = 0.1
iterations = 300
hidden_size = 100
pixels_per_image = 784
num_labels = 10
batch_size = 100

# %%
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error = 0.0
    correct_count = 0
    
    for i in range(int(len(images) / batch_size)):
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        
        batch_start, batch_end = (i * batch_size, (i+1) * batch_size)
        layer_0 = images[batch_start:batch_end]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_1 *= dropout_mask * 2
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((layer_2 - labels[batch_start:batch_end]) ** 2)
        for k in range(batch_size):
            correct_count += int(np.argmax(layer_2[k:k+1]) == np.argmax(labels[batch_start+k:batch_start+k+1]))
        
        layer_2_delta = (layer_2 - labels[batch_start:batch_end]) / batch_size
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        layer_1_delta *= dropout_mask
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)
    
    if not j % 10 or j == iterations - 1:
        test_error = 0.0
        test_correct_count = 0
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            
            test_error += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
            test_correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
        print("\nI:" + str(j) + " Train error:" + str(error/float(len(images)))[0:5] + " Train accuracy:" + str(correct_count/float(len(images))))
        print("Test error:" + str(test_error/float(len(test_images)))[0:5] + " Test accuracy:" + str(test_correct_count/float(len(test_images))))
i = 0
layer_0 = images[i:i+1]
# Out:
# I:0 Train error:1.344 Train accuracy:0.161
# Test error:0.829 Test accuracy:0.3751
#
# I:10 Train error:0.613 Train accuracy:0.656
# Test error:0.558 Test accuracy:0.733
#
# I:20 Train error:0.513 Train accuracy:0.74
# Test error:0.471 Test accuracy:0.7828
#
# I:30 Train error:0.449 Train accuracy:0.779
# Test error:0.419 Test accuracy:0.8048
#
# I:40 Train error:0.406 Train accuracy:0.817
# Test error:0.383 Test accuracy:0.8194
#
# I:50 Train error:0.373 Train accuracy:0.844
# Test error:0.362 Test accuracy:0.8314
#
# I:60 Train error:0.362 Train accuracy:0.857
# Test error:0.346 Test accuracy:0.8379
#
# I:70 Train error:0.346 Train accuracy:0.857
# Test error:0.336 Test accuracy:0.8451
#
# I:80 Train error:0.325 Train accuracy:0.866
# Test error:0.323 Test accuracy:0.8527
#
# I:90 Train error:0.314 Train accuracy:0.886
# Test error:0.317 Test accuracy:0.8569
#
# I:100 Train error:0.304 Train accuracy:0.896
# Test error:0.313 Test accuracy:0.8583
#
# I:110 Train error:0.299 Train accuracy:0.897
# Test error:0.307 Test accuracy:0.861
#
# I:120 Train error:0.292 Train accuracy:0.907
# Test error:0.303 Test accuracy:0.8629
#
# I:130 Train error:0.282 Train accuracy:0.911
# Test error:0.300 Test accuracy:0.8661
#
# I:140 Train error:0.272 Train accuracy:0.91
# Test error:0.297 Test accuracy:0.8678
#
# I:150 Train error:0.263 Train accuracy:0.916
# Test error:0.295 Test accuracy:0.8693
#
# I:160 Train error:0.262 Train accuracy:0.912
# Test error:0.293 Test accuracy:0.8708
#
# I:170 Train error:0.256 Train accuracy:0.928
# Test error:0.291 Test accuracy:0.8731
#
# I:180 Train error:0.261 Train accuracy:0.942
# Test error:0.288 Test accuracy:0.8732
#
# I:190 Train error:0.250 Train accuracy:0.926
# Test error:0.287 Test accuracy:0.8731
#
# I:200 Train error:0.241 Train accuracy:0.932
# Test error:0.283 Test accuracy:0.8741
#
# I:210 Train error:0.254 Train accuracy:0.934
# Test error:0.289 Test accuracy:0.8748
#
# I:220 Train error:0.256 Train accuracy:0.926
# Test error:0.287 Test accuracy:0.8742
#
# I:230 Train error:0.234 Train accuracy:0.94
# Test error:0.284 Test accuracy:0.8757
#
# I:240 Train error:0.229 Train accuracy:0.945
# Test error:0.283 Test accuracy:0.8765
#
# I:250 Train error:0.235 Train accuracy:0.944
# Test error:0.279 Test accuracy:0.8772
#
# I:260 Train error:0.241 Train accuracy:0.946
# Test error:0.282 Test accuracy:0.8772
#
# I:270 Train error:0.236 Train accuracy:0.953
# Test error:0.280 Test accuracy:0.8784
#
# I:280 Train error:0.228 Train accuracy:0.948
# Test error:0.281 Test accuracy:0.8774
#
# I:290 Train error:0.210 Train accuracy:0.959
# Test error:0.278 Test accuracy:0.8765
#
# I:299 Train error:0.221 Train accuracy:0.956
# Test error:0.282 Test accuracy:0.8759
