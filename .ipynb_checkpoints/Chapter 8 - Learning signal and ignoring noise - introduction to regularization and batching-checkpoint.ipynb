# %%
# Overfitting MNIST

# %%
import numpy as np
from keras.datasets import mnist
np.random.seed(1)

# %%
relu = lambda x: (x > 0) * x
relu2deriv = lambda x: x > 0

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
images, labels = (x_train[0:1000].reshape(1000, 28*28) / 255, y_train[0:1000])

# %%
one_hot_labels = np.zeros((len(labels), 10))
for i, l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

# %%
test_images = x_test.reshape(len(x_test), 28*28) / 255

# %%
test_labels = np.zeros((len(y_test), 10))
for i, l in enumerate(y_test):
    test_labels[i][l] = 1

# %%
alpha = 0.005
iterations = 350
hidden_size = 40
pixels_per_image = 784
num_labels = 10

# %%
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error = 0.0
    correct_count = 0
    
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((layer_2 - labels[i:i+1]) **2)
        correct_count += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        
        layer_2_delta = layer_2 - labels[i:i+1]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)

    print("\nI:" + str(j) + " Error:" + str(error/float(len(images)))[0:5] + " Correct:" + str(correct_count/float(len(images))))
    
    if not j % 10 or j == iterations - 1:
        error = 0.0
        correct_count = 0
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            
            error += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
            correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
        print("\nTest error:" + str(error/float(len(test_images)))[0:5] + " Test accuracy:" + str(correct_count/float(len(test_images))))
# Out:
# I:0 Error:0.003 Correct:0.999
# Test error:0.355 Test accuracy:0.8291
#
# I:1 Error:0.003 Correct:0.999
#
# I:2 Error:0.003 Correct:0.999
#
# I:3 Error:0.003 Correct:0.999
#
# I:4 Error:0.003 Correct:0.999
#
# I:5 Error:0.003 Correct:0.999
#
# I:6 Error:0.003 Correct:0.999
#
# I:7 Error:0.003 Correct:0.999
#
# I:8 Error:0.003 Correct:0.999
#
# I:9 Error:0.003 Correct:0.999
#
# I:10 Error:0.003 Correct:0.999
# Test error:0.356 Test accuracy:0.8288
#
# I:11 Error:0.003 Correct:0.999
#
# I:12 Error:0.003 Correct:0.999
#
# I:13 Error:0.003 Correct:0.999
#
# I:14 Error:0.003 Correct:0.999
#
# I:15 Error:0.003 Correct:0.999
#
# I:16 Error:0.003 Correct:0.999
#
# I:17 Error:0.003 Correct:0.999
#
# I:18 Error:0.003 Correct:0.999
#
# I:19 Error:0.003 Correct:0.999
#
# I:20 Error:0.003 Correct:0.999
# Test error:0.357 Test accuracy:0.8287
#
# I:21 Error:0.003 Correct:0.999
#
# I:22 Error:0.003 Correct:0.999
#
# I:23 Error:0.003 Correct:0.999
#
# I:24 Error:0.003 Correct:0.999
#
# I:25 Error:0.003 Correct:0.999
#
# I:26 Error:0.003 Correct:0.999
#
# I:27 Error:0.003 Correct:0.999
#
# I:28 Error:0.003 Correct:0.999
#
# I:29 Error:0.003 Correct:0.999
#
# I:30 Error:0.003 Correct:0.999
# Test error:0.357 Test accuracy:0.8281
#
# I:31 Error:0.003 Correct:0.999
#
# I:32 Error:0.003 Correct:0.999
#
# I:33 Error:0.003 Correct:0.999
#
# I:34 Error:0.003 Correct:0.999
#
# I:35 Error:0.003 Correct:0.999
#
# I:36 Error:0.003 Correct:0.999
#
# I:37 Error:0.003 Correct:0.999
#
# I:38 Error:0.003 Correct:0.999
#
# I:39 Error:0.003 Correct:0.999
#
# I:40 Error:0.003 Correct:0.999
# Test error:0.358 Test accuracy:0.8276
#
# I:41 Error:0.003 Correct:0.999
#
# I:42 Error:0.003 Correct:0.999
#
# I:43 Error:0.003 Correct:0.999
#
# I:44 Error:0.003 Correct:0.999
#
# I:45 Error:0.003 Correct:0.999
#
# I:46 Error:0.003 Correct:0.999
#
# I:47 Error:0.003 Correct:0.999
#
# I:48 Error:0.003 Correct:0.999
#
# I:49 Error:0.003 Correct:0.999
#
# I:50 Error:0.003 Correct:0.999
# Test error:0.359 Test accuracy:0.8272
#
# I:51 Error:0.003 Correct:0.999
#
# I:52 Error:0.003 Correct:0.999
#
# I:53 Error:0.003 Correct:0.999
#
# I:54 Error:0.002 Correct:0.999
#
# I:55 Error:0.002 Correct:0.999
#
# I:56 Error:0.002 Correct:0.999
#
# I:57 Error:0.002 Correct:0.999
#
# I:58 Error:0.002 Correct:0.999
#
# I:59 Error:0.002 Correct:0.999
#
# I:60 Error:0.002 Correct:0.999
# Test error:0.359 Test accuracy:0.8278
#
# I:61 Error:0.002 Correct:0.999
#
# I:62 Error:0.002 Correct:0.999
#
# I:63 Error:0.002 Correct:0.999
#
# I:64 Error:0.002 Correct:0.999
#
# I:65 Error:0.002 Correct:0.999
#
# I:66 Error:0.002 Correct:0.999
#
# I:67 Error:0.002 Correct:0.999
#
# I:68 Error:0.002 Correct:0.999
#
# I:69 Error:0.002 Correct:0.999
#
# I:70 Error:0.002 Correct:0.999
# Test error:0.360 Test accuracy:0.8282
#
# I:71 Error:0.002 Correct:0.999
#
# I:72 Error:0.002 Correct:0.999
#
# I:73 Error:0.002 Correct:0.999
#
# I:74 Error:0.002 Correct:0.999
#
# I:75 Error:0.002 Correct:0.999
#
# I:76 Error:0.002 Correct:0.999
#
# I:77 Error:0.002 Correct:0.999
#
# I:78 Error:0.002 Correct:0.999
#
# I:79 Error:0.002 Correct:0.999
#
# I:80 Error:0.002 Correct:0.999
# Test error:0.360 Test accuracy:0.8278
#
# I:81 Error:0.002 Correct:0.999
#
# I:82 Error:0.002 Correct:0.999
#
# I:83 Error:0.002 Correct:0.999
#
# I:84 Error:0.002 Correct:0.999
#
# I:85 Error:0.002 Correct:0.999
#
# I:86 Error:0.002 Correct:0.999
#
# I:87 Error:0.002 Correct:0.999
#
# I:88 Error:0.002 Correct:0.999
#
# I:89 Error:0.002 Correct:0.999
#
# I:90 Error:0.002 Correct:0.999
# Test error:0.360 Test accuracy:0.8277
#
# I:91 Error:0.002 Correct:0.999
#
# I:92 Error:0.002 Correct:0.999
#
# I:93 Error:0.002 Correct:0.999
#
# I:94 Error:0.002 Correct:0.999
#
# I:95 Error:0.002 Correct:0.999
#
# I:96 Error:0.002 Correct:0.999
#
# I:97 Error:0.002 Correct:0.999
#
# I:98 Error:0.002 Correct:0.999
#
# I:99 Error:0.002 Correct:0.999
#
# I:100 Error:0.002 Correct:1.0
# Test error:0.361 Test accuracy:0.828
#
# I:101 Error:0.002 Correct:1.0
#
# I:102 Error:0.002 Correct:0.999
#
# I:103 Error:0.002 Correct:1.0
#
# I:104 Error:0.002 Correct:1.0
#
# I:105 Error:0.002 Correct:1.0
#
# I:106 Error:0.002 Correct:1.0
#
# I:107 Error:0.002 Correct:1.0
#
# I:108 Error:0.002 Correct:1.0
#
# I:109 Error:0.002 Correct:1.0
#
# I:110 Error:0.002 Correct:1.0
# Test error:0.361 Test accuracy:0.8271
#
# I:111 Error:0.002 Correct:1.0
#
# I:112 Error:0.002 Correct:1.0
#
# I:113 Error:0.002 Correct:1.0
#
# I:114 Error:0.002 Correct:1.0
#
# I:115 Error:0.002 Correct:1.0
#
# I:116 Error:0.002 Correct:1.0
#
# I:117 Error:0.002 Correct:1.0
#
# I:118 Error:0.002 Correct:1.0
#
# I:119 Error:0.002 Correct:1.0
#
# I:120 Error:0.002 Correct:1.0
# Test error:0.362 Test accuracy:0.8274
#
# I:121 Error:0.002 Correct:1.0
#
# I:122 Error:0.002 Correct:1.0
#
# I:123 Error:0.002 Correct:1.0
#
# I:124 Error:0.002 Correct:1.0
#
# I:125 Error:0.002 Correct:1.0
#
# I:126 Error:0.002 Correct:1.0
#
# I:127 Error:0.002 Correct:1.0
#
# I:128 Error:0.002 Correct:1.0
#
# I:129 Error:0.002 Correct:1.0
#
# I:130 Error:0.002 Correct:1.0
# Test error:0.362 Test accuracy:0.8269
#
# I:131 Error:0.002 Correct:1.0
#
# I:132 Error:0.002 Correct:1.0
#
# I:133 Error:0.002 Correct:1.0
#
# I:134 Error:0.002 Correct:1.0
#
# I:135 Error:0.002 Correct:1.0
#
# I:136 Error:0.002 Correct:1.0
#
# I:137 Error:0.002 Correct:1.0
#
# I:138 Error:0.002 Correct:1.0
#
# I:139 Error:0.002 Correct:1.0
#
# I:140 Error:0.002 Correct:1.0
# Test error:0.362 Test accuracy:0.826
#
# I:141 Error:0.002 Correct:1.0
#
# I:142 Error:0.002 Correct:1.0
#
# I:143 Error:0.002 Correct:1.0
#
# I:144 Error:0.002 Correct:1.0
#
# I:145 Error:0.002 Correct:1.0
#
# I:146 Error:0.002 Correct:1.0
#
# I:147 Error:0.002 Correct:1.0
#
# I:148 Error:0.002 Correct:1.0
#
# I:149 Error:0.002 Correct:1.0
#
# I:150 Error:0.002 Correct:1.0
# Test error:0.363 Test accuracy:0.8262
#
# I:151 Error:0.002 Correct:1.0
#
# I:152 Error:0.002 Correct:1.0
#
# I:153 Error:0.002 Correct:1.0
#
# I:154 Error:0.002 Correct:1.0
#
# I:155 Error:0.002 Correct:1.0
#
# I:156 Error:0.002 Correct:1.0
#
# I:157 Error:0.002 Correct:1.0
#
# I:158 Error:0.002 Correct:1.0
#
# I:159 Error:0.002 Correct:1.0
#
# I:160 Error:0.002 Correct:1.0
# Test error:0.363 Test accuracy:0.8262
#
# I:161 Error:0.002 Correct:1.0
#
# I:162 Error:0.002 Correct:1.0
#
# I:163 Error:0.002 Correct:1.0
#
# I:164 Error:0.002 Correct:1.0
#
# I:165 Error:0.002 Correct:1.0
#
# I:166 Error:0.002 Correct:1.0
#
# I:167 Error:0.002 Correct:1.0
#
# I:168 Error:0.002 Correct:1.0
#
# I:169 Error:0.002 Correct:1.0
#
# I:170 Error:0.002 Correct:1.0
# Test error:0.363 Test accuracy:0.8259
#
# I:171 Error:0.002 Correct:1.0
#
# I:172 Error:0.002 Correct:1.0
#
# I:173 Error:0.002 Correct:1.0
#
# I:174 Error:0.002 Correct:1.0
#
# I:175 Error:0.002 Correct:1.0
#
# I:176 Error:0.002 Correct:1.0
#
# I:177 Error:0.002 Correct:1.0
#
# I:178 Error:0.002 Correct:1.0
#
# I:179 Error:0.002 Correct:1.0
#
# I:180 Error:0.002 Correct:1.0
# Test error:0.363 Test accuracy:0.8259
#
# I:181 Error:0.002 Correct:1.0
#
# I:182 Error:0.002 Correct:1.0
#
# I:183 Error:0.002 Correct:1.0
#
# I:184 Error:0.002 Correct:1.0
#
# I:185 Error:0.002 Correct:1.0
#
# I:186 Error:0.002 Correct:1.0
#
# I:187 Error:0.002 Correct:1.0
#
# I:188 Error:0.002 Correct:1.0
#
# I:189 Error:0.002 Correct:1.0
#
# I:190 Error:0.002 Correct:1.0
# Test error:0.364 Test accuracy:0.826
#
# I:191 Error:0.002 Correct:1.0
#
# I:192 Error:0.002 Correct:1.0
#
# I:193 Error:0.002 Correct:1.0
#
# I:194 Error:0.002 Correct:1.0
#
# I:195 Error:0.002 Correct:1.0
#
# I:196 Error:0.002 Correct:1.0
#
# I:197 Error:0.001 Correct:1.0
#
# I:198 Error:0.001 Correct:1.0
#
# I:199 Error:0.001 Correct:1.0
#
# I:200 Error:0.001 Correct:1.0
# Test error:0.364 Test accuracy:0.8259
#
# I:201 Error:0.001 Correct:1.0
#
# I:202 Error:0.001 Correct:1.0
#
# I:203 Error:0.001 Correct:1.0
#
# I:204 Error:0.001 Correct:1.0
#
# I:205 Error:0.001 Correct:1.0
#
# I:206 Error:0.001 Correct:1.0
#
# I:207 Error:0.001 Correct:1.0
#
# I:208 Error:0.001 Correct:1.0
#
# I:209 Error:0.001 Correct:1.0
#
# I:210 Error:0.001 Correct:1.0
# Test error:0.364 Test accuracy:0.8257
#
# I:211 Error:0.001 Correct:1.0
#
# I:212 Error:0.001 Correct:1.0
#
# I:213 Error:0.001 Correct:1.0
#
# I:214 Error:0.001 Correct:1.0
#
# I:215 Error:0.001 Correct:1.0
#
# I:216 Error:0.001 Correct:1.0
#
# I:217 Error:0.001 Correct:1.0
#
# I:218 Error:0.001 Correct:1.0
#
# I:219 Error:0.001 Correct:1.0
#
# I:220 Error:0.001 Correct:1.0
# Test error:0.364 Test accuracy:0.8253
#
# I:221 Error:0.001 Correct:1.0
#
# I:222 Error:0.001 Correct:1.0
#
# I:223 Error:0.001 Correct:1.0
#
# I:224 Error:0.001 Correct:1.0
#
# I:225 Error:0.001 Correct:1.0
#
# I:226 Error:0.001 Correct:1.0
#
# I:227 Error:0.001 Correct:1.0
#
# I:228 Error:0.001 Correct:1.0
#
# I:229 Error:0.001 Correct:1.0
#
# I:230 Error:0.001 Correct:1.0
# Test error:0.364 Test accuracy:0.8252
#
# I:231 Error:0.001 Correct:1.0
# I:232 Error:0.001 Correct:1.0
#
# I:233 Error:0.001 Correct:1.0
#
# I:234 Error:0.001 Correct:1.0
#
# I:235 Error:0.001 Correct:1.0
#
# I:236 Error:0.001 Correct:1.0
#
# I:237 Error:0.001 Correct:1.0
#
# I:238 Error:0.001 Correct:1.0
#
# I:239 Error:0.001 Correct:1.0
#
# I:240 Error:0.001 Correct:1.0
# Test error:0.365 Test accuracy:0.8251
#
# I:241 Error:0.001 Correct:1.0
#
# I:242 Error:0.001 Correct:1.0
#
# I:243 Error:0.001 Correct:1.0
#
# I:244 Error:0.001 Correct:1.0
#
# I:245 Error:0.001 Correct:1.0
#
# I:246 Error:0.001 Correct:1.0
#
# I:247 Error:0.001 Correct:1.0
#
# I:248 Error:0.001 Correct:1.0
#
# I:249 Error:0.001 Correct:1.0
#
# I:250 Error:0.001 Correct:1.0
# Test error:0.365 Test accuracy:0.8247
#
# I:251 Error:0.001 Correct:1.0
#
# I:252 Error:0.001 Correct:1.0
#
# I:253 Error:0.001 Correct:1.0
#
# I:254 Error:0.001 Correct:1.0
#
# I:255 Error:0.001 Correct:1.0
#
# I:256 Error:0.001 Correct:1.0
#
# I:257 Error:0.001 Correct:1.0
#
# I:258 Error:0.001 Correct:1.0
#
# I:259 Error:0.001 Correct:1.0
#
# I:260 Error:0.001 Correct:1.0
# Test error:0.365 Test accuracy:0.8246
#
# I:261 Error:0.001 Correct:1.0
#
# I:262 Error:0.001 Correct:1.0
#
# I:263 Error:0.001 Correct:1.0
#
# I:264 Error:0.001 Correct:1.0
#
# I:265 Error:0.001 Correct:1.0
#
# I:266 Error:0.001 Correct:1.0
#
# I:267 Error:0.001 Correct:1.0
#
# I:268 Error:0.001 Correct:1.0
#
# I:269 Error:0.001 Correct:1.0
#
# I:270 Error:0.001 Correct:1.0
# Test error:0.365 Test accuracy:0.8243
#
# I:271 Error:0.001 Correct:1.0
#
# I:272 Error:0.001 Correct:1.0
#
# I:273 Error:0.001 Correct:1.0
#
# I:274 Error:0.001 Correct:1.0
#
# I:275 Error:0.001 Correct:1.0
#
# I:276 Error:0.001 Correct:1.0
#
# I:277 Error:0.001 Correct:1.0
#
# I:278 Error:0.001 Correct:1.0
#
# I:279 Error:0.001 Correct:1.0
#
# I:280 Error:0.001 Correct:1.0
# Test error:0.365 Test accuracy:0.8243
#
# I:281 Error:0.001 Correct:1.0
#
# I:282 Error:0.001 Correct:1.0
#
# I:283 Error:0.001 Correct:1.0
#
# I:284 Error:0.001 Correct:1.0
#
# I:285 Error:0.001 Correct:1.0
#
# I:286 Error:0.001 Correct:1.0
#
# I:287 Error:0.001 Correct:1.0
#
# I:288 Error:0.001 Correct:1.0
#
# I:289 Error:0.001 Correct:1.0
#
# I:290 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.8237
#
# I:291 Error:0.001 Correct:1.0
#
# I:292 Error:0.001 Correct:1.0
#
# I:293 Error:0.001 Correct:1.0
#
# I:294 Error:0.001 Correct:1.0
#
# I:295 Error:0.001 Correct:1.0
#
# I:296 Error:0.001 Correct:1.0
#
# I:297 Error:0.001 Correct:1.0
#
# I:298 Error:0.001 Correct:1.0
#
# I:299 Error:0.001 Correct:1.0
#
# I:300 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.8238
#
# I:301 Error:0.001 Correct:1.0
#
# I:302 Error:0.001 Correct:1.0
#
# I:303 Error:0.001 Correct:1.0
#
# I:304 Error:0.001 Correct:1.0
#
# I:305 Error:0.001 Correct:1.0
#
# I:306 Error:0.001 Correct:1.0
#
# I:307 Error:0.001 Correct:1.0
#
# I:308 Error:0.001 Correct:1.0
#
# I:309 Error:0.001 Correct:1.0
#
# I:310 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.824
#
# I:311 Error:0.001 Correct:1.0
#
# I:312 Error:0.001 Correct:1.0
#
# I:313 Error:0.001 Correct:1.0
#
# I:314 Error:0.001 Correct:1.0
#
# I:315 Error:0.001 Correct:1.0
#
# I:316 Error:0.001 Correct:1.0
#
# I:317 Error:0.001 Correct:1.0
#
# I:318 Error:0.001 Correct:1.0
#
# I:319 Error:0.001 Correct:1.0
#
# I:320 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.8237
#
# I:321 Error:0.001 Correct:1.0
#
# I:322 Error:0.001 Correct:1.0
#
# I:323 Error:0.001 Correct:1.0
#
# I:324 Error:0.001 Correct:1.0
#
# I:325 Error:0.001 Correct:1.0
#
# I:326 Error:0.001 Correct:1.0
#
# I:327 Error:0.001 Correct:1.0
#
# I:328 Error:0.001 Correct:1.0
#
# I:329 Error:0.001 Correct:1.0
#
# I:330 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.8239
#
# I:331 Error:0.001 Correct:1.0
#
# I:332 Error:0.001 Correct:1.0
#
# I:333 Error:0.001 Correct:1.0
#
# I:334 Error:0.001 Correct:1.0
#
# I:335 Error:0.001 Correct:1.0
#
# I:336 Error:0.001 Correct:1.0
#
# I:337 Error:0.001 Correct:1.0
#
# I:338 Error:0.001 Correct:1.0
#
# I:339 Error:0.001 Correct:1.0
#
# I:340 Error:0.001 Correct:1.0
# Test error:0.366 Test accuracy:0.8236
#
# I:341 Error:0.001 Correct:1.0
#
# I:342 Error:0.001 Correct:1.0
#
# I:343 Error:0.001 Correct:1.0
#
# I:344 Error:0.001 Correct:1.0
#
# I:345 Error:0.001 Correct:1.0
#
# I:346 Error:0.001 Correct:1.0
#
# I:347 Error:0.001 Correct:1.0
#
# I:348 Error:0.001 Correct:1.0
#
# I:349 Error:0.001 Correct:1.0
# Test error:0.367 Test accuracy:0.8237

# %%
# Dropout

# %%
alpha = 0.005
iterations = 350
hidden_size = 40
pixels_per_image = 784
num_labels = 10

# %%
weights_0_1 = 0.2 * np.random.random((pixels_per_image, hidden_size)) - 0.1
weights_1_2 = 0.2 * np.random.random((hidden_size, num_labels)) - 0.1

# %%
for j in range(iterations):
    error = 0.0
    correct_count = 0
    
    for i in range(len(images)):
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0, weights_0_1))
        layer_1 *= dropout_mask
        layer_2 = np.dot(layer_1, weights_1_2)
        
        error += np.sum((layer_2 - labels[i:i+1]) **2)
        correct_count += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        
        layer_2_delta = layer_2 - labels[i:i+1]
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        layer_1_delta *= dropout_mask
        
        weights_1_2 -= alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 -= alpha * layer_0.T.dot(layer_1_delta)
    
    if not j % 10 or j == iterations - 1:
        error = 0.0
        correct_count = 0
        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0, weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)
            
            error += np.sum((layer_2 - test_labels[i:i+1]) ** 2)
            correct_count += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))
        
        print("\nI:" + str(j) + " Error:" + str(error/float(len(images)))[0:5] + " Correct:" + str(correct_count/float(len(images))))
        print("\nTest error:" + str(error/float(len(test_images)))[0:5] + " Test accuracy:" + str(correct_count/float(len(test_images))))
i = 0
layer_0 = images[i:i+1]
# Out:
# I:0 Error:0.904 Correct:0.233
#
# Test error:0.772 Test accuracy:0.4891
#
# I:1 Error:0.771 Correct:0.441
#
# I:2 Error:0.704 Correct:0.51
#
# I:3 Error:0.658 Correct:0.582
#
# I:4 Error:0.616 Correct:0.608
#
# I:5 Error:0.592 Correct:0.629
#
# I:6 Error:0.556 Correct:0.661
#
# I:7 Error:0.534 Correct:0.67
#
# I:8 Error:0.517 Correct:0.7
#
# I:9 Error:0.488 Correct:0.723
#
# I:10 Error:0.468 Correct:0.738
#
# Test error:0.501 Test accuracy:0.8042
#
# I:11 Error:0.475 Correct:0.747
#
# I:12 Error:0.448 Correct:0.767
#
# I:13 Error:0.428 Correct:0.783
#
# I:14 Error:0.423 Correct:0.783
#
# I:15 Error:0.421 Correct:0.792
#
# I:16 Error:0.415 Correct:0.786
#
# I:17 Error:0.417 Correct:0.789
#
# I:18 Error:0.417 Correct:0.792
#
# I:19 Error:0.397 Correct:0.784
#
# I:20 Error:0.386 Correct:0.814
#
# Test error:0.507 Test accuracy:0.8443
#
# I:21 Error:0.373 Correct:0.826
#
# I:22 Error:0.386 Correct:0.817
#
# I:23 Error:0.392 Correct:0.801
#
# I:24 Error:0.392 Correct:0.799
#
# I:25 Error:0.372 Correct:0.823
#
# I:26 Error:0.366 Correct:0.828
#
# I:27 Error:0.373 Correct:0.822
#
# I:28 Error:0.356 Correct:0.826
#
# I:29 Error:0.371 Correct:0.82
#
# I:30 Error:0.363 Correct:0.835
#
# Test error:0.500 Test accuracy:0.8525
#
# I:31 Error:0.344 Correct:0.841
#
# I:32 Error:0.337 Correct:0.86
#
# I:33 Error:0.364 Correct:0.833
#
# I:34 Error:0.339 Correct:0.856
#
# I:35 Error:0.350 Correct:0.862
#
# I:36 Error:0.327 Correct:0.867
#
# I:37 Error:0.350 Correct:0.839
#
# I:38 Error:0.348 Correct:0.828
#
# I:39 Error:0.368 Correct:0.81
#
# I:40 Error:0.338 Correct:0.86
#
# Test error:0.569 Test accuracy:0.8614
#
# I:41 Error:0.344 Correct:0.843
#
# I:42 Error:0.355 Correct:0.84
#
# I:43 Error:0.330 Correct:0.853
#
# I:44 Error:0.329 Correct:0.853
#
# I:45 Error:0.329 Correct:0.863
#
# I:46 Error:0.337 Correct:0.855
#
# I:47 Error:0.329 Correct:0.857
#
# I:48 Error:0.324 Correct:0.864
#
# I:49 Error:0.313 Correct:0.876
#
# I:50 Error:0.325 Correct:0.858
#
# Test error:0.504 Test accuracy:0.8619
#
# I:51 Error:0.326 Correct:0.859
#
# I:52 Error:0.317 Correct:0.856
#
# I:53 Error:0.335 Correct:0.857
#
# I:54 Error:0.325 Correct:0.855
#
# I:55 Error:0.320 Correct:0.86
#
# I:56 Error:0.332 Correct:0.857
#
# I:57 Error:0.313 Correct:0.868
#
# I:58 Error:0.320 Correct:0.866
#
# I:59 Error:0.313 Correct:0.866
#
# I:60 Error:0.327 Correct:0.855
#
# Test error:0.541 Test accuracy:0.8652
#
# I:61 Error:0.310 Correct:0.883
#
# I:62 Error:0.317 Correct:0.862
#
# I:63 Error:0.312 Correct:0.875
#
# I:64 Error:0.312 Correct:0.874
#
# I:65 Error:0.310 Correct:0.871
#
# I:66 Error:0.311 Correct:0.882
#
# I:67 Error:0.294 Correct:0.901
#
# I:68 Error:0.299 Correct:0.885
#
# I:69 Error:0.302 Correct:0.869
#
# I:70 Error:0.304 Correct:0.872
#
# Test error:0.564 Test accuracy:0.8625
#
# I:71 Error:0.294 Correct:0.887
#
# I:72 Error:0.303 Correct:0.878
#
# I:73 Error:0.302 Correct:0.88
#
# I:74 Error:0.292 Correct:0.889
#
# I:75 Error:0.300 Correct:0.889
#
# I:76 Error:0.306 Correct:0.887
#
# I:77 Error:0.285 Correct:0.891
#
# I:78 Error:0.299 Correct:0.873
#
# I:79 Error:0.293 Correct:0.887
#
# I:80 Error:0.276 Correct:0.892
#
# Test error:0.617 Test accuracy:0.8561
#
# I:81 Error:0.276 Correct:0.903
#
# I:82 Error:0.292 Correct:0.885
#
# I:83 Error:0.298 Correct:0.888
#
# I:84 Error:0.285 Correct:0.897
#
# I:85 Error:0.290 Correct:0.895
#
# I:86 Error:0.297 Correct:0.884
#
# I:87 Error:0.286 Correct:0.886
#
# I:88 Error:0.297 Correct:0.884
#
# I:89 Error:0.292 Correct:0.888
#
# I:90 Error:0.301 Correct:0.883
#
# Test error:0.634 Test accuracy:0.8551
#
# I:91 Error:0.276 Correct:0.912
#
# I:92 Error:0.302 Correct:0.886
#
# I:93 Error:0.276 Correct:0.893
#
# I:94 Error:0.290 Correct:0.885
#
# I:95 Error:0.286 Correct:0.886
#
# I:96 Error:0.289 Correct:0.886
#
# I:97 Error:0.281 Correct:0.885
#
# I:98 Error:0.274 Correct:0.895
#
# I:99 Error:0.290 Correct:0.884
#
# I:100 Error:0.254 Correct:0.91
#
# Test error:0.586 Test accuracy:0.857
#
# I:101 Error:0.276 Correct:0.903
#
# I:102 Error:0.275 Correct:0.903
#
# I:103 Error:0.285 Correct:0.89
#
# I:104 Error:0.272 Correct:0.906
#
# I:105 Error:0.279 Correct:0.899
#
# I:106 Error:0.286 Correct:0.886
#
# I:107 Error:0.281 Correct:0.895
#
# I:108 Error:0.260 Correct:0.904
#
# I:109 Error:0.278 Correct:0.893
#
# I:110 Error:0.263 Correct:0.91
#
# Test error:0.648 Test accuracy:0.854
#
# I:111 Error:0.275 Correct:0.901
#
# I:112 Error:0.272 Correct:0.908
#
# I:113 Error:0.290 Correct:0.885
#
# I:114 Error:0.277 Correct:0.897
#
# I:115 Error:0.277 Correct:0.902
#
# I:116 Error:0.289 Correct:0.892
#
# I:117 Error:0.273 Correct:0.898
#
# I:118 Error:0.281 Correct:0.885
#
# I:119 Error:0.283 Correct:0.889
#
# I:120 Error:0.290 Correct:0.894
#
# Test error:0.628 Test accuracy:0.8491
#
# I:121 Error:0.250 Correct:0.907
#
# I:122 Error:0.270 Correct:0.886
#
# I:123 Error:0.279 Correct:0.884
#
# I:124 Error:0.278 Correct:0.894
#
# I:125 Error:0.280 Correct:0.888
#
# I:126 Error:0.279 Correct:0.884
#
# I:127 Error:0.268 Correct:0.891
#
# I:128 Error:0.276 Correct:0.894
#
# I:129 Error:0.271 Correct:0.895
#
# I:130 Error:0.272 Correct:0.892
#
# Test error:0.599 Test accuracy:0.8548
#
# I:131 Error:0.281 Correct:0.89
#
# I:132 Error:0.269 Correct:0.905
#
# I:133 Error:0.262 Correct:0.903
#
# I:134 Error:0.285 Correct:0.886
#
# I:135 Error:0.258 Correct:0.911
#
# I:136 Error:0.264 Correct:0.893
#
# I:137 Error:0.279 Correct:0.889
#
# I:138 Error:0.277 Correct:0.89
#
# I:139 Error:0.270 Correct:0.9
#
# I:140 Error:0.263 Correct:0.899
#
# Test error:0.658 Test accuracy:0.8459
#
# I:141 Error:0.279 Correct:0.895
#
# I:142 Error:0.283 Correct:0.892
#
# I:143 Error:0.253 Correct:0.913
#
# I:144 Error:0.258 Correct:0.919
#
# I:145 Error:0.248 Correct:0.913
#
# I:146 Error:0.268 Correct:0.892
#
# I:147 Error:0.272 Correct:0.906
#
# I:148 Error:0.266 Correct:0.889
#
# I:149 Error:0.273 Correct:0.898
#
# I:150 Error:0.272 Correct:0.898
#
# Test error:0.591 Test accuracy:0.847
#
# I:151 Error:0.264 Correct:0.903
#
# I:152 Error:0.273 Correct:0.894
#
# I:153 Error:0.279 Correct:0.888
#
# I:154 Error:0.256 Correct:0.905
#
# I:155 Error:0.275 Correct:0.897
#
# I:156 Error:0.256 Correct:0.897
#
# I:157 Error:0.264 Correct:0.9
#
# I:158 Error:0.263 Correct:0.906
#
# I:159 Error:0.253 Correct:0.91
#
# I:160 Error:0.254 Correct:0.908
#
# Test error:0.649 Test accuracy:0.8542
#
# I:161 Error:0.268 Correct:0.901
#
# I:162 Error:0.262 Correct:0.912
#
# I:163 Error:0.261 Correct:0.905
#
# I:164 Error:0.241 Correct:0.914
#
# I:165 Error:0.260 Correct:0.909
#
# I:166 Error:0.253 Correct:0.903
#
# I:167 Error:0.281 Correct:0.899
#
# I:168 Error:0.257 Correct:0.897
#
# I:169 Error:0.266 Correct:0.905
#
# I:170 Error:0.258 Correct:0.905
#
# Test error:0.573 Test accuracy:0.8453
#
# I:171 Error:0.254 Correct:0.904
#
# I:172 Error:0.245 Correct:0.915
#
# I:173 Error:0.269 Correct:0.894
#
# I:174 Error:0.280 Correct:0.895
#
# I:175 Error:0.260 Correct:0.904
#
# I:176 Error:0.260 Correct:0.904
#
# I:177 Error:0.254 Correct:0.901
#
# I:178 Error:0.264 Correct:0.896
#
# I:179 Error:0.270 Correct:0.878
#
# I:180 Error:0.247 Correct:0.919
#
# Test error:0.654 Test accuracy:0.8445
#
# I:181 Error:0.245 Correct:0.918
#
# I:182 Error:0.269 Correct:0.902
#
# I:183 Error:0.245 Correct:0.916
#
# I:184 Error:0.261 Correct:0.91
#
# I:185 Error:0.255 Correct:0.912
#
# I:186 Error:0.262 Correct:0.904
#
# I:187 Error:0.253 Correct:0.911
#
# I:188 Error:0.252 Correct:0.91
#
# I:189 Error:0.253 Correct:0.917
#
# I:190 Error:0.251 Correct:0.924
#
# Test error:0.555 Test accuracy:0.8445
#
# I:191 Error:0.260 Correct:0.899
#
# I:192 Error:0.260 Correct:0.905
#
# I:193 Error:0.279 Correct:0.887
#
# I:194 Error:0.250 Correct:0.908
#
# I:195 Error:0.277 Correct:0.891
#
# I:196 Error:0.252 Correct:0.902
#
# I:197 Error:0.248 Correct:0.913
#
# I:198 Error:0.241 Correct:0.927
#
# I:199 Error:0.257 Correct:0.911
#
# I:200 Error:0.253 Correct:0.913
#
# Test error:0.619 Test accuracy:0.8515
#
# I:201 Error:0.257 Correct:0.905
#
# I:202 Error:0.255 Correct:0.903
#
# I:203 Error:0.261 Correct:0.904
#
# I:204 Error:0.245 Correct:0.92
#
# I:205 Error:0.246 Correct:0.911
#
# I:206 Error:0.255 Correct:0.907
#
# I:207 Error:0.273 Correct:0.891
#
# I:208 Error:0.259 Correct:0.901
#
# I:209 Error:0.261 Correct:0.898
#
# I:210 Error:0.239 Correct:0.906
#
# Test error:0.623 Test accuracy:0.8472
#
# I:211 Error:0.251 Correct:0.904
#
# I:212 Error:0.249 Correct:0.91
#
# I:213 Error:0.258 Correct:0.897
#
# I:214 Error:0.247 Correct:0.915
#
# I:215 Error:0.260 Correct:0.903
#
# I:216 Error:0.254 Correct:0.899
#
# I:217 Error:0.251 Correct:0.905
#
# I:218 Error:0.260 Correct:0.908
#
# I:219 Error:0.264 Correct:0.897
#
# I:220 Error:0.260 Correct:0.903
#
# Test error:0.587 Test accuracy:0.8465
#
# I:221 Error:0.264 Correct:0.889
#
# I:222 Error:0.259 Correct:0.909
#
# I:223 Error:0.243 Correct:0.908
#
# I:224 Error:0.243 Correct:0.912
#
# I:225 Error:0.242 Correct:0.913
# I:226 Error:0.267 Correct:0.89
#
# I:227 Error:0.263 Correct:0.905
#
# I:228 Error:0.255 Correct:0.907
#
# I:229 Error:0.267 Correct:0.886
#
# I:230 Error:0.249 Correct:0.907
#
# Test error:0.600 Test accuracy:0.8409
#
# I:231 Error:0.244 Correct:0.91
#
# I:232 Error:0.258 Correct:0.905
#
# I:233 Error:0.258 Correct:0.911
#
# I:234 Error:0.257 Correct:0.899
#
# I:235 Error:0.260 Correct:0.902
#
# I:236 Error:0.252 Correct:0.911
#
# I:237 Error:0.252 Correct:0.912
#
# I:238 Error:0.239 Correct:0.922
#
# I:239 Error:0.262 Correct:0.912
#
# I:240 Error:0.258 Correct:0.905
#
# Test error:0.683 Test accuracy:0.837
#
# I:241 Error:0.256 Correct:0.907
#
# I:242 Error:0.251 Correct:0.909
#
# I:243 Error:0.244 Correct:0.918
#
# I:244 Error:0.242 Correct:0.921
#
# I:245 Error:0.264 Correct:0.892
#
# I:246 Error:0.271 Correct:0.897
#
# I:247 Error:0.259 Correct:0.907
#
# I:248 Error:0.245 Correct:0.911
#
# I:249 Error:0.233 Correct:0.929
#
# I:250 Error:0.248 Correct:0.912
#
# Test error:0.691 Test accuracy:0.8429
#
# I:251 Error:0.257 Correct:0.907
#
# I:252 Error:0.237 Correct:0.916
#
# I:253 Error:0.254 Correct:0.904
#
# I:254 Error:0.245 Correct:0.916
#
# I:255 Error:0.256 Correct:0.906
#
# I:256 Error:0.263 Correct:0.892
#
# I:257 Error:0.240 Correct:0.92
#
# I:258 Error:0.230 Correct:0.913
#
# I:259 Error:0.249 Correct:0.906
#
# I:260 Error:0.264 Correct:0.9
#
# Test error:0.657 Test accuracy:0.8347
#
# I:261 Error:0.240 Correct:0.908
#
# I:262 Error:0.247 Correct:0.906
#
# I:263 Error:0.254 Correct:0.897
#
# I:264 Error:0.245 Correct:0.915
#
# I:265 Error:0.254 Correct:0.902
#
# I:266 Error:0.253 Correct:0.891
#
# I:267 Error:0.251 Correct:0.911
#
# I:268 Error:0.251 Correct:0.905
#
# I:269 Error:0.247 Correct:0.913
#
# I:270 Error:0.257 Correct:0.912
#
# Test error:0.689 Test accuracy:0.8383
#
# I:271 Error:0.253 Correct:0.899
#
# I:272 Error:0.265 Correct:0.89
#
# I:273 Error:0.245 Correct:0.915
#
# I:274 Error:0.278 Correct:0.879
#
# I:275 Error:0.254 Correct:0.911
#
# I:276 Error:0.244 Correct:0.916
#
# I:277 Error:0.238 Correct:0.92
#
# I:278 Error:0.243 Correct:0.908
#
# I:279 Error:0.255 Correct:0.905
#
# I:280 Error:0.256 Correct:0.901
#
# Test error:0.750 Test accuracy:0.8428
#
# I:281 Error:0.245 Correct:0.91
#
# I:282 Error:0.258 Correct:0.904
#
# I:283 Error:0.255 Correct:0.895
#
# I:284 Error:0.253 Correct:0.904
#
# I:285 Error:0.234 Correct:0.917
#
# I:286 Error:0.232 Correct:0.924
#
# I:287 Error:0.236 Correct:0.92
#
# I:288 Error:0.238 Correct:0.91
#
# I:289 Error:0.241 Correct:0.919
#
# I:290 Error:0.246 Correct:0.912
#
# Test error:0.721 Test accuracy:0.8423
#
# I:291 Error:0.242 Correct:0.905
#
# I:292 Error:0.251 Correct:0.905
#
# I:293 Error:0.236 Correct:0.916
